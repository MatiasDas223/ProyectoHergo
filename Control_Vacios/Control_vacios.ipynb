# %% [markdown]
# Descargar e importar todas las librerias necesarias

# %%
#pip install pandas
#pip install schedule

# %%
#pip install openpyxl

# %%
import pandas as pd #'Pandas'
import schedule #'Para automatizar procesos en funcion del dia'
import time 
import glob #'Para buscar el ultimo archivo en una carpeta'
import os
import pyexcel as pe
from datetime import datetime
from tabulate import tabulate
from pandas.io.formats import format as pd_format
import os
import sys
import subprocess

# %%
### VENTAS ###

directorio_archivos = r"\\layla\Documentos\STOCK\ReporteVacios"

patron_archivo = os.path.join(directorio_archivos, 'Ventas*.xls') #Aca va el tipo de archivo

archivos = glob.glob(patron_archivo)

archivos = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True) #Ordenar archivos por el ultimo modificado

archivo_excel_original = archivos[0]

archivo_excel_destino = archivo_excel_original + "x"

# Comando para abrir el archivo de Excel original
comando_abrir = 'start "{}"'.format(archivo_excel_original)

# Ejecutar el comando para abrir el archivo de Excel original
subprocess.run(comando_abrir, shell=True)

# Esperar unos segundos para asegurarse de que Excel esté abierto y listo
# Ajusta este tiempo según sea necesario
time.sleep(2)

# Comando de PowerShell para guardar el archivo de Excel como .xlsx
comando_guardar = 'powershell -c "$excel = New-Object -ComObject Excel.Application; $workbook = $excel.Workbooks.Open(\'{}\'); $workbook.SaveAs(\'{}\', 51); $excel.Quit()"'.format(archivo_excel_original, archivo_excel_destino)

# Ejecutar el comando para guardar el archivo de Excel como .xlsx
subprocess.run(comando_guardar, shell=False)

# DESCARGAS

directorio_archivos = r"\\layla\Documentos\STOCK\ReporteVacios"

patron_archivo = os.path.join(directorio_archivos, 'Descargas*.xls') #Aca va el tipo de archivo

archivos = glob.glob(patron_archivo)

archivos = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True) #Ordenar archivos por el ultimo modificado

archivo_excel_original = archivos[0]

archivo_excel_destino = archivo_excel_original + "x"

# Comando para abrir el archivo de Excel original
comando_abrir = 'start "{}"'.format(archivo_excel_original)

# Ejecutar el comando para abrir el archivo de Excel original
subprocess.run(comando_abrir, shell=True)

# Esperar unos segundos para asegurarse de que Excel esté abierto y listo
# Ajusta este tiempo según sea necesario
time.sleep(2)

# Comando de PowerShell para guardar el archivo de Excel como .xlsx
comando_guardar = 'powershell -c "$excel = New-Object -ComObject Excel.Application; $workbook = $excel.Workbooks.Open(\'{}\'); $workbook.SaveAs(\'{}\', 51); $excel.Quit()"'.format(archivo_excel_original, archivo_excel_destino)

# Ejecutar el comando para guardar el archivo de Excel como .xlsx
subprocess.run(comando_guardar, shell=False)


# COMODATOS

directorio_archivos = r"\\layla\Documentos\STOCK\ReporteVacios"

patron_archivo = os.path.join(directorio_archivos, 'Vacios*.xls') #Aca va el tipo de archivo

archivos = glob.glob(patron_archivo)

archivos = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True) #Ordenar archivos por el ultimo modificado

archivo_excel_original = archivos[0]

archivo_excel_destino = archivo_excel_original + "x"

# Comando para abrir el archivo de Excel original
comando_abrir = 'start "{}"'.format(archivo_excel_original)

# Ejecutar el comando para abrir el archivo de Excel original
subprocess.run(comando_abrir, shell=True)

# Esperar unos segundos para asegurarse de que Excel esté abierto y listo
# Ajusta este tiempo según sea necesario
time.sleep(2)

# Comando de PowerShell para guardar el archivo de Excel como .xlsx
comando_guardar = 'powershell -c "$excel = New-Object -ComObject Excel.Application; $workbook = $excel.Workbooks.Open(\'{}\'); $workbook.SaveAs(\'{}\', 51); $excel.Quit()"'.format(archivo_excel_original, archivo_excel_destino)

# Ejecutar el comando para guardar el archivo de Excel como .xlsx
subprocess.run(comando_guardar, shell=False)
# Out:
# CompletedProcess(args='powershell -c "$excel = New-Object -ComObject Excel.Application; $workbook = $excel.Workbooks.Open(\'\\\\layla\\Documentos\\STOCK\\ReporteVacios\\VaciosDesde2562023.xls\'); $workbook.SaveAs(\'\\\\layla\\Documentos\\STOCK\\ReporteVacios\\VaciosDesde2562023.xlsx\', 51); $excel.Quit()"', returncode=0)

# %% [markdown]
# Archivo con fleteros

# %%
bd_fleteros = pd.read_excel('../Control_Vacios/bd_fleteros.xlsx')

# %% [markdown]
# ## TRABAJO CON ARCHIVO VENTAS

# %% [markdown]
# Definir el patron del archivo a cargar

# %%
patron_archivo = 'VentasDesde*.xlsx'

# %% [markdown]
# Obtener la lista de archivos en una carpeta a traves de glob

# %%
directorio_archivos = r'\\layla\\Documentos\\STOCK\\ReporteVacios'

patron_archivo = os.path.join(directorio_archivos, 'Ventas*.xlsx')

archivos = glob.glob(patron_archivo)

# %% [markdown]
# Ordeanamos los archivos del mas reciente al mas viejo

# %%
archivos_ordenados = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True)

# %% [markdown]
# Seleccionamos el archivo mas nuevo

# %%
archivo_ventas = archivos_ordenados[0]
columnas= ['fecha', 'reparto', 'entrada', 'salida', 'articulo_a', 'cliente', 'proveedo']
df_ventas = pd.read_excel(archivo_ventas, usecols = columnas)
df_ventas = df_ventas.rename(columns={'proveedo' : 'Codigo_Fletero'})
df_ventas = df_ventas.merge(bd_fleteros, on = 'Codigo_Fletero')
df_vent_clientes = df_ventas

# %%
articulos_especificos = [9951, 19099, 20789, 20791, 21149, 18873, 23926, 20993, 9376, 21836, 9838, 9364, 9953
, 22475, 22643, 20826]

df_ventas = df_ventas[df_ventas['articulo_a'].isin(articulos_especificos)]

# %% [markdown]
# Creo una columa con los saldos y luego voy a acumular el saldo de cada precarga

# %% [markdown]
# Cambiar el formato de la fecha al tradicional

# %%
# Creamos la funcion para transformar la fecha

def cambiar_formato_fecha(fecha_str):
    fecha_obj = datetime.strptime(fecha_str, "%d-%b-%y")
    return fecha_obj.strftime("%d-%m-%Y")

# %%
# Aplica la función a cada valor de la columna "fecha"

df_ventas['fecha'] = df_ventas['fecha'].apply(cambiar_formato_fecha)
df_vent_clientes['fecha'] = df_vent_clientes['fecha'].apply(cambiar_formato_fecha)
# Out:
# C:\Users\mdasilva\AppData\Local\Temp\ipykernel_4048\2830692580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ventas['fecha'] = df_ventas['fecha'].apply(cambiar_formato_fecha)

# %%
df_ventas['saldo'] = df_ventas['salida']
# Out:
# C:\Users\mdasilva\AppData\Local\Temp\ipykernel_4048\721155652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ventas['saldo'] = df_ventas['salida']

# %%
df_ventas
# Out:
#             fecha cliente  articulo_a  entrada  salida  reparto  \
# 0      21-01-2023   12867        9376        0       2   451733
# 1      21-01-2023   14836        9838        0       8   451733
# 2      21-01-2023   14836        9951        0       5   451733
# 3      21-01-2023   14836       18873        0       8   451733
# 4      21-01-2023   14836       21836        0      10   451733
# ...           ...     ...         ...      ...     ...      ...
# 28332  06-06-2023   00242       22643        0       1   464649
# 28333  06-06-2023   D3309        9951        0       1   464649
# 28334  06-06-2023   D3309       19099        0       1   464649
# 28335  06-06-2023   D3309       20826        0       1   464649
# 28336  06-06-2023   H9287       19099        0       1   464649
#
#       Codigo_Fletero Codigo Cliente                     Nombre  saldo
# 0              F0031          H7632  FLETERO IVECO 1 ETCHVERRY      2
# 1              F0031          H7632  FLETERO IVECO 1 ETCHVERRY      8
# 2              F0031          H7632  FLETERO IVECO 1 ETCHVERRY      5
# 3              F0031          H7632  FLETERO IVECO 1 ETCHVERRY      8
# 4              F0031          H7632  FLETERO IVECO 1 ETCHVERRY     10
# ...              ...            ...                        ...    ...
# 28332          F0252          H7630          FLETERO MORALES 5      1
# 28333          F0252          H7630          FLETERO MORALES 5      1
# 28334          F0252          H7630          FLETERO MORALES 5      1
# 28335          F0252          H7630          FLETERO MORALES 5      1
# 28336          F0252          H7630          FLETERO MORALES 5      1
#
# [27886 rows x 10 columns]

# %%
# Vamos a agrupar los valores por fecha y por reparto

# De la fecha tomamos el valor minimo que es el dia en el que el reparto fue abierto, y el saldo lo sumamos para acumularlo

df_ventas = df_ventas.groupby(['reparto', 'Codigo Cliente']).agg({'saldo': 'sum', 'fecha' : 'min'}).reset_index() # Agrupar por reparto, agregando la suma del saldo y el valor minimo de fecha
df_ventas = df_ventas.sort_values('fecha', ascending = False) # Ordenar por fecha
df_ventas['fecha'] = pd.to_datetime(df_ventas['fecha']).dt.date # Pasar la fecha al formato correcto
columnas = ['fecha','Codigo Cliente', 'reparto', 'saldo'] # Aca ordenamos las columnas en el orden deseado
df_ventas = df_ventas.reindex(columns=columnas) # Idem aca para odenar
# Out:
# C:\Users\mdasilva\AppData\Local\Temp\ipykernel_4048\2882092669.py:7: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_ventas['fecha'] = pd.to_datetime(df_ventas['fecha']).dt.date # Pasar la fecha al formato correcto

# %%
df_ventas
# Out:
#            fecha Codigo Cliente  reparto  saldo
# 1914  2023-05-31          H7608   464173      4
# 1906  2023-05-31          H7614   464157     29
# 1912  2023-05-31          H7609   464169     37
# 1911  2023-05-31          H7624   464165      9
# 1910  2023-05-31          H7622   464165      9
# ...          ...            ...      ...    ...
# 175   2023-02-01          H7611   453057     41
# 174   2023-02-01          H7623   453055     59
# 173   2023-02-01          H7621   453053     20
# 172   2023-02-01          H7616   453051     75
# 178   2023-02-01          H7628   453063     43
#
# [2223 rows x 4 columns]

# %%
df_ventas = df_ventas.rename(columns={'Codigo Cliente' : 'Cod_Fletero'})
columnas = ['fecha', 'reparto','Cod_Fletero', 'saldo']
df_ventas = df_ventas.reindex(columns=columnas) # Idem aca para odenar
df_ventas
# Out:
#            fecha  reparto Cod_Fletero  saldo
# 1914  2023-05-31   464173       H7608      4
# 1906  2023-05-31   464157       H7614     29
# 1912  2023-05-31   464169       H7609     37
# 1911  2023-05-31   464165       H7624      9
# 1910  2023-05-31   464165       H7622      9
# ...          ...      ...         ...    ...
# 175   2023-02-01   453057       H7611     41
# 174   2023-02-01   453055       H7623     59
# 173   2023-02-01   453053       H7621     20
# 172   2023-02-01   453051       H7616     75
# 178   2023-02-01   453063       H7628     43
#
# [2223 rows x 4 columns]

# %% [markdown]
# Filtrar entre que fechas queremos el reporte

# %%
from interfaz_fechas import obtener_fechas

fechas = obtener_fechas()

fecha_limite = fechas[0].strftime("%d/%m/%Y") # Fecha desde

fecha_actual = fechas[1].strftime("%d/%m/%Y") # Fecha hasta

fecha_limite = datetime.strptime(fecha_limite, "%d/%m/%Y").date()
fecha_actual = datetime.strptime(fecha_actual, "%d/%m/%Y").date()

df_ventas = df_ventas[(df_ventas['fecha'] >= fecha_limite) & (df_ventas['fecha'] <= fecha_actual)]

# %% [markdown]
# ## TRABAJO CON ARCHIVO DESCARGAS

# %% [markdown]
# ### Obtener la lista de archivos en una carpeta a traves de glob

# %%
directorio_archivos = r'\\layla\\Documentos\\STOCK\\ReporteVacios'

patron_archivo = os.path.join(directorio_archivos, 'Descargas*.xlsx')

archivos = glob.glob(patron_archivo)

# %% [markdown]
# ### Ordeanamos los archivos del mas reciente al mas viejo

# %%
archivos_ordenados = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True)

# %% [markdown]
# ### Seleccionamos el archivo mas nuevo

# %%
archivo_descargas = archivos_ordenados[0]
columnas= ['reparto', 'entrada', 'salida', 'articulo_a']
df_descargas = pd.read_excel(archivo_descargas, usecols = columnas)
print(df_descargas)
# Out:
#        articulo_a  entrada  salida  reparto
# 0            9346      1.0       0   433158
# 1            9345   3132.0       0   444628
# 2            9346    261.0       0   444628
# 3            9375     20.0       0   444718
# 4            9345   1200.0       0   444746
# ...           ...      ...     ...      ...
# 12214        9345    228.0       0   466091
# 12215        9346     19.0       0   466091
# 12216        9345    156.0       0   466096
# 12217        9346     13.0       0   466096
# 12218      810218      1.0       0   466096
#
# [12219 rows x 4 columns]

# %%
# Filtramos el df por los articulos que corresponden a cajones, sacando las botellas, latas etc.

articulos_especificos = [9346, 9376, 9364, 9389, 9838, 9951, 9953, 18873, 19099, 20789, 20791,20826
, 20993, 21149, 21836, 22475, 22642, 22643, 23134, 23926]

df_descargas = df_descargas[df_descargas['articulo_a'].isin(articulos_especificos)]

# %% [markdown]
# ### Eliminamos duplicados

# %%
df_descargas = df_descargas.loc[(df_descargas.shift() != df_descargas).any(axis=1)]

# %% [markdown]
# ### Creamos la columna saldo

# %%
df_descargas['regreso'] = df_descargas['entrada'] - df_descargas['salida']

# %%
# Vamos a agrupar los valores por reparto

# De la fecha tomamos el valor minimo que es el dia en el que el reparto fue abierto, y el saldo lo sumamos para acumularlo

df_descargas = df_descargas.groupby(['reparto']).agg({'regreso': 'sum'}).reset_index() # Agrupar por reparto, agregando la suma del saldo
df_descargas = df_descargas.sort_values('reparto', ascending = False) # Ordenar por reparto
columnas = ['reparto', 'regreso'] # Aca ordenamos las columnas en el orden deseado
df_descargas = df_descargas.reindex(columns=columnas) # Idem aca para odenar

# %% [markdown]
# ### UNIMOS LOS DF VENTAS Y DESCARGAS

# %%
df_merged = df_ventas.merge(df_descargas, on='reparto', how='left') #Unimos con un left join asi nos trae todos los de ventas
df_merged['regreso'] = df_merged['regreso'].fillna(0).astype(int) #Si hay alguno en ventas que no coincide con descargas le pone 0

#df_merged = df_merged[df_merged['saldo'] != df_merged['regreso']] #Me quedo solo con los que son distintos, los otros estan OK

# %%
#Obtenemos los numeros de los repartos que no coinciden sus saldos

numeros_reparto = df_merged['reparto'].unique().tolist()

# %% [markdown]
# ### AHORA TRABAJAMOS CON EL DF COMODATOS

# %%
directorio_archivos = r'\\layla\\Documentos\\STOCK\\ReporteVacios'

patron_archivo = os.path.join(directorio_archivos, 'Vacios*.xlsx')

archivos = glob.glob(patron_archivo)

# %%
archivos_ordenados = sorted(archivos, key=lambda x: os.path.getmtime(x), reverse=True)

# %%
import re

archivo_comodatos = archivos_ordenados[0]
columnas= ['debe', 'articulo', 'cliente', 'fecha']
df_comodatos = pd.read_excel(archivo_comodatos, usecols = columnas)

# Limpiar caracteres no numéricos de la columna articulos

df_comodatos['articulo'] = df_comodatos['articulo'].apply(lambda x: re.sub('[^0-9]', '', str(x)))
df_comodatos['articulo'] = df_comodatos['articulo'].replace('', '0')
df_comodatos['articulo'] = df_comodatos['articulo'].astype(float).astype(pd.Int64Dtype())

# %%
#Arreglamos el formato de la fecha

df_comodatos['fecha'] = df_comodatos['fecha'].apply(cambiar_formato_fecha)

# %%
articulos_especificos = [9346, 9389]

df_comodatos = df_comodatos[df_comodatos['articulo'].isin(articulos_especificos)]

# %%
df_comodatos.rename(columns={'debe' : 'comodato'}, inplace=True) #renombramos para que se llame igual a las demas
df_comodatos['fecha'] = pd.to_datetime(df_comodatos['fecha'], format='%d-%m-%Y')

# %%
df_comodatos
# Out:
#           fecha cliente  articulo  comodato
# 1    2023-01-21   H7612      9346         4
# 3    2023-01-21   H7611      9346         0
# 5    2023-01-21   H7611      9389         0
# 7    2023-01-21   C4895      9346        20
# 9    2023-01-23   01001      9346         0
# ...         ...     ...       ...       ...
# 9169 2023-06-22   01062      9346         6
# 9171 2023-06-22   01062      9346        11
# 9173 2023-06-22   H9550      9346        15
# 9175 2023-06-23   01052      9346       300
# 9179 2023-06-24   H7612      9346         2
#
# [4560 rows x 4 columns]

# %% [markdown]
# ### Vamos a iterar los repartos con diferencia

# %%
for numero_reparto in numeros_reparto:
    # Filtrar la tabla Ventas por el número de reparto actual
    df_vent = df_vent_clientes[df_vent_clientes['reparto'] == numero_reparto]
    fletero = df_vent_clientes['Codigo Cliente'][df_vent_clientes['reparto'] == numero_reparto].unique().tolist()
    
    # Obtener la lista de clientes únicos en la tabla Ventas del reparto actual
    clientes_reparto = df_vent['cliente'].unique().tolist()
    
    # Filtrar la tabla Comodatos por las fechas dentro del rango de 3 días posteriores a la fecha del reparto actual
    fechas_reparto = df_merged[df_merged['reparto'] == numero_reparto]['fecha']
    fechas_rango = [fecha + pd.DateOffset(days=dias) for fecha in fechas_reparto for dias in range(1, 6)]
    comodatos_reparto = df_comodatos[df_comodatos['fecha'].isin(fechas_rango)]
    comodatos_fletero = comodatos_reparto[comodatos_reparto['cliente'].isin(fletero)]
    comodatos_fletero = comodatos_fletero.groupby('cliente')['comodato'].sum().reset_index()
    
   # Calcular la cantidad de comodatos realizados a cada cliente en el reparto actual
    comodatos_cliente = comodatos_reparto[comodatos_reparto['cliente'].isin(clientes_reparto)]
    comodatos_por_cliente = comodatos_cliente.groupby('cliente')['comodato'].sum().reset_index()

    # Verificar si hay al menos una fila en comodatos_por_cliente
    if not comodatos_por_cliente.empty :

        valor_comodato = comodatos_por_cliente['comodato'].values[0]

    # Agregar la columna de comodatos a la tabla Merged
        df_merged.loc[df_merged['reparto'] == numero_reparto, 'comodato'] = valor_comodato
    else:
        df_merged.loc[df_merged['reparto'] == numero_reparto, 'comodato'] = 0  # O cualquier otro valor predeterminado en caso de no haber comodatos
# Imprimir la tabla Merged actualizada
    if not comodatos_fletero.empty:
        df_merged.loc[df_merged['reparto'] == numero_reparto, 'CMfletero'] = comodatos_fletero['comodato'].values[0]
    else:
        df_merged.loc[df_merged['reparto'] == numero_reparto, 'CMfletero'] = 0
        
print(df_merged)
# Out:
#            fecha  reparto Cod_Fletero  saldo  regreso  comodato  CMfletero
# 0     2023-05-31   464173       H7608      4        4       0.0        1.0
# 1     2023-05-31   464157       H7614     29       29       0.0        1.0
# 2     2023-05-31   464169       H7609     37       37       0.0        0.0
# 3     2023-05-31   464165       H7624      9        9       0.0        7.0
# 4     2023-05-31   464165       H7622      9        9       0.0        7.0
# ...          ...      ...         ...    ...      ...       ...        ...
# 2218  2023-02-01   453057       H7611     41       41       0.0        0.0
# 2219  2023-02-01   453055       H7623     59       56       3.0        0.0
# 2220  2023-02-01   453053       H7621     20       20       0.0        0.0
# 2221  2023-02-01   453051       H7616     75       70      25.0        5.0
# 2222  2023-02-01   453063       H7628     43       43       0.0        0.0
#
# [2223 rows x 7 columns]

# %%
fechas_rango
# Out:
# [Timestamp('2023-02-02 00:00:00'),
#  Timestamp('2023-02-03 00:00:00'),
#  Timestamp('2023-02-04 00:00:00'),
#  Timestamp('2023-02-05 00:00:00'),
#  Timestamp('2023-02-06 00:00:00')]

# %% [markdown]
# ### Ahora configuramos para imprimir

# %%
from tabulate import tabulate

# Crear una lista de listas con los datos de la tabla
tabla = []
for _, row in df_merged.iterrows():
    fila = [
        row['fecha'],
        row['reparto'],
        row['saldo'],
        row['regreso'],
        row['comodato'],
        '',
    ]
    tabla.append(fila)

# Configurar opciones de formato
opciones = {
    'headers': ['Fecha', 'Reparto', 'Salida', 'Regreso', 'Comodato', 'Verificación'],
    'tablefmt': 'pretty',  # Formato de la tabla (opciones: plain, simple, grid, fancy_grid, ...)
}

# Imprimir la tabla
print(tabulate(tabla, **opciones))
# Out:
# +------------+---------+--------+---------+----------+--------------+
# |   Fecha    | Reparto | Salida | Regreso | Comodato | Verificación |
# +------------+---------+--------+---------+----------+--------------+
# | 2023-05-31 | 464173  |   4    |    4    |   0.0    |              |
# | 2023-05-31 | 464157  |   29   |   29    |   0.0    |              |
# | 2023-05-31 | 464169  |   37   |   37    |   0.0    |              |
# | 2023-05-31 | 464165  |   9    |    9    |   0.0    |              |
# | 2023-05-31 | 464165  |   9    |    9    |   0.0    |              |
# | 2023-05-31 | 464163  |   15   |   15    |   0.0    |              |
# | 2023-05-31 | 464161  |   27   |   26    |   0.0    |              |
# | 2023-05-31 | 464159  |   14   |   14    |   0.0    |              |
# | 2023-05-31 | 464155  |   19   |   19    |   0.0    |              |
# | 2023-05-31 | 464171  |   16   |   16    |   0.0    |              |
# | 2023-05-31 | 464153  |   14   |   14    |   0.0    |              |
# | 2023-05-31 | 464151  |   15   |   15    |   0.0    |              |
# | 2023-05-31 | 464149  |   14   |   14    |   0.0    |              |
# | 2023-05-31 | 464147  |   19   |   19    |   0.0    |              |
# | 2023-05-31 | 464144  |   10   |   10    |   0.0    |              |
# | 2023-05-31 | 464103  |   7    |    7    |   0.0    |              |
# | 2023-05-31 | 464175  |   4    |    4    |   0.0    |              |
# | 2023-03-31 | 458940  |   4    |    4    |   0.0    |              |
# | 2023-03-31 | 458867  |   2    |    2    |   0.0    |              |
# | 2023-03-31 | 458910  |  111   |   111   |   0.0    |              |
# | 2023-03-31 | 458912  |   37   |   37    |   0.0    |              |
# | 2023-03-31 | 458914  |   6    |    6    |   0.0    |              |
# | 2023-03-31 | 458916  |   1    |    1    |   0.0    |              |
# | 2023-03-31 | 458917  |   34   |   35    |   0.0    |              |
# | 2023-03-31 | 458919  |   31   |   32    |   0.0    |              |
# | 2023-03-31 | 458921  |   28   |   28    |   0.0    |              |
# | 2023-03-31 | 458922  |   25   |   25    |   0.0    |              |
# | 2023-03-31 | 458924  |   9    |    8    |   0.0    |              |
# | 2023-03-31 | 458928  |   12   |   12    |   0.0    |              |
# | 2023-03-31 | 458930  |   15   |   15    |   0.0    |              |
# | 2023-03-31 | 458933  |   15   |   15    |   0.0    |              |
# | 2023-03-31 | 458934  |   58   |    7    |   50.0   |              |
# | 2023-03-31 | 458942  |   5    |    5    |   0.0    |              |
# | 2023-03-31 | 458908  |   50   |   50    |   0.0    |              |
# | 2023-03-31 | 458921  |   28   |   28    |   0.0    |              |
# | 2023-01-31 | 452935  |   93   |   33    |   10.0   |              |
# | 2023-02-01 | 453063  |   43   |   43    |   0.0    |              |
# +------------+---------+--------+---------+----------+--------------+

# %% [markdown]
# ### Mandar a imprimir a una impresora fisica

# %%
import pandas as pd
from fpdf import FPDF

# Crear una clase PDF personalizada
class PDF(FPDF):
    def header(self):
        # Configurar la cabecera del PDF
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, 'Tabla de Datos', 0, 1, 'C')
        self.ln(5)

    def footer(self):
        # Configurar el pie de página del PDF
        self.set_y(-15)
        self.set_font('Arial', 'I', 8)
        self.cell(0, 10, 'Página %s' % self.page_no(), 0, 0, 'C')

    def chapter_title(self, title):
        # Configurar el título del capítulo
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'L')
        self.ln(5)

    def chapter_body(self, data):
        # Configurar el cuerpo del capítulo con los datos de la tabla
        self.set_font('Arial', '', 10)
        self.cell(25, 10, 'Fecha', 1, 0, 'C')
        self.cell(25, 10, 'Reparto', 1, 0, 'C')
        self.cell(25, 10, 'Fletero', 1, 0, 'C')
        self.cell(25, 10, 'Salida', 1, 0, 'C')
        self.cell(25, 10, 'Regreso', 1, 0, 'C')
        self.cell(25, 10, 'Comodato', 1, 0, 'C')
        self.cell(25, 10, 'Verificación', 1, 1, 'C')
        self.cell(25,10,'CMfletero',1 ,1 ,'C' )

        for index, row in data.iterrows():
            self.cell(25, 10, str(row['fecha']), 1, 0, 'C')
            self.cell(25, 10, str(row['reparto']), 1, 0, 'C')
            self.cell(25, 10, str(row['Cod_Fletero']), 1, 0, 'C')
            self.cell(25, 10, str(row['saldo']), 1, 0, 'C')
            self.cell(25, 10, str(row['regreso']), 1, 0, 'C')
            self.cell(25, 10, str(row['comodato']), 1, 0, 'C')
            self.cell(25, 10, str(row['CMfletero']), 1, 0, 'C')
            self.cell(25, 10, '', 1, 1, 'C')  # Casilla de verificación vacía

# Crear el objeto PDF
pdf = PDF()
pdf.add_page()

# Agregar el contenido al PDF
pdf.chapter_body(df_merged)

# Guardar el PDF en un archivo
pdf_filename = 'tabla_datos.pdf'
pdf.output(pdf_filename)
# Out:
# ''

# %%
import subprocess

def imprimir_pdf(pdf_filename):
    try:
        subprocess.Popen(['C:\Program Files\Adobe\Acrobat DC\Acrobat\Acrobat.exe', '/p', '/h', pdf_filename])
        print("El archivo PDF se ha enviado para imprimir.")
    except Exception as e:
        print("Error al imprimir el archivo PDF:", str(e))

# Llamar a la función de impresión del archivo PDF
pdf_filename = r'C:\Users\mdasilva\Desktop\Contro Vacios\tabla_datos.pdf'
#imprimir_pdf(pdf_filename)

# %% [markdown]
# Generamos excel

# %%
# Especificar la ruta y el nombre del archivo de Excel
ruta_archivo = r'H:\\LOGISTICA\\Marcelo Ortega\\envases semanal\\'

nombre_archivo = 'ControlVacios_' + str(fecha_actual) + '.xlsx'

ruta_completa = os.path.join(ruta_archivo, nombre_archivo) #Aca va el tipo de archivo

# Guardar el DataFrame df_merged en un archivo de Excel
df_merged.to_excel(ruta_completa, index=False)
